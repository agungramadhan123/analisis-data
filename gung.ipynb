# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
df = pd.read_csv('Instagram-Data.csv')
df.head(15)
# Out:
#    Country  Rank         Account                Title  \
# 0      All     1       cristiano    Cristiano Ronaldo
# 1      All     2     kyliejenner              Kylie 🤍
# 2      All     3        leomessi            Leo Messi
# 3      All     4   kendalljenner              Kendall
# 4      All     5     selenagomez         Selena Gomez
# 5      All     6         zendaya              Zendaya
# 6      All     7   kimkardashian  Kim Kardashian West
# 7      All     8         beyonce             Beyoncé
# 8      All     9    arianagrande        Ariana Grande
# 9      All    10    billieeilish        BILLIE EILISH
# 10     All    11        neymarjr                NJ 🇧🇷
# 11     All    12    lalalalisa_m                 LISA
# 12     All    13  jennierubyjane                    J
# 13     All    14  tomholland2013          Tom Holland
# 14     All    15     virat.kohli          Virat Kohli
#
#                                          Link  \
# 0        https://www.instagram.com/cristiano/
# ...

# %%
df.isna().sum()
# Out:
# Country                  0
# Rank                     0
# Account                  0
# Title                   17
# Link                     0
# Category                91
# Followers                0
# Audience Country         7
# Authentic engagement     0
# Engagement avg           0
# Scraped                  0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
#cek data informasi

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Country               1000 non-null   object
#  1   Rank                  1000 non-null   int64
#  2   Account               1000 non-null   object
#  3   Title                 983 non-null    object
#  4   Link                  1000 non-null   object
#  5   Category              909 non-null    object
#  6   Followers             1000 non-null   int64
#  7   Audience Country      993 non-null    object
#  8   Authentic engagement  1000 non-null   int64
#  9   Engagement avg        1000 non-null   int64
#  10  Scraped               1000 non-null   object
# dtypes: int64(4), object(7)
# memory usage: 86.1+ KB

# %% [markdown]
# cara konversi type data

# %%
# df['Pregnancies']=df['Pregnancies'].astype('float') # type data bebas kita mau milih yang mana, jika kolom info itu tidak sesuai dengan df,head

# %%
plt.figure(figsize=(10,5))
hitung_korelasi=df.corr(method='pearson')
hitung_korelasi
sns.heatmap(hitung_korelasi, annot=True)
plt.title('korelasi matriks of the dataset')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 2
#       1 plt.figure(figsize=(10,5))
# ----> 2 hitung_korelasi=df.corr(method='pearson')
#       3 hitung_korelasi
#       4 sns.heatmap(hitung_korelasi, annot=True)
#
# File c:\Users\M. Agung Ramadhan\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File c:\Users\M. Agung Ramadhan\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:1993, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1991 if dtype is not None:
#    1992     dtype = np.dtype(dtype)
# ...

# %%
age = df['Age']
pregnancies = df['Pregnancies']

sns.scatterplot(x=age, y=pregnancies, hue=df['Outcome'])
plt.show()

# %% [markdown]
# Data yang diberikan dari grafik terlihat bahwa sebaran pasien yang terkena diabetes cenderung menyebar dari semua range data umur.
# Ini menunjukkan bahwa tidak ada informasi yang kuat atau relasi yang kuat mengenai `Age` dan `Pregnancies`.

# %%
sns.scatterplot(x=df['Outcome'], y=df['Glucose'])
plt.show()

# %% [markdown]
# Tidak didapatkan faktor informasi yang terkait antara `Outcome` dengan level `Glucose`

# %%
print(f"Banyak pasien yang tidak terkena diabetes: {len(df[df['Outcome'] == 0])}")
print(f"Banyak pasien yang terkena diabetes: {len(df[df['Outcome'] == 1])}")
# Out:
# Banyak pasien yang tidak terkena diabetes: 500
# Banyak pasien yang terkena diabetes: 268

# %%
df['Outcome'].value_counts()
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %%
proporsi_diabetes = df['Outcome'].value_counts()

plt.pie(proporsi_diabetes.values, autopct="%.1f", labels= proporsi_diabetes.index)
plt.show()

# %%
len(df[df['Outcome'] == 1])
# Out:
# 268

# %%
plt.figure(figsize=(10,8))
sns.histplot(data=df, x='Age', hue='Outcome', multiple='stack')
plt.title('Distribusi data Umur berdasarkan Outcome')
plt.show()

# %% [markdown]
# Bahwa range 20 - 30 merupakan puncak dari pasien yang terkena diabetes. Saran yang bisa dikasih yaitu: Lebih memerhatikan pasien yang berumur di range tersebut.

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(x=df['Insulin'], y=df['SkinThickness'], hue=df['Outcome'])

plt.title('Skin Thickness & Insulin Relation')
plt.show()

# %% [markdown]
# Semakin Tinggi `SkinThickness` dan semakin tinggi level `Insulin` berarti kemungkinan bahwa pasien tersebut terkena Diabetes berdasarkan hasil grafik diatas.

# %%
insuline= df['Insulin']
glokosa=df['Glucose']
sns.scatterplot(x=insuline, y=glokosa, hue=df['Outcome'])
plt.show()

# %% [markdown]
# data yang di dapatkan bahwa bahwa sebaran di atas bahwa tinggin nya glokosa dan tinggi nya insulin tubuh pasien dapat menyebabkan diabetes
